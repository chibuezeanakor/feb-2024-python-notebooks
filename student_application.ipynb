# %% [markdown]
# - Create a student database
# - Print report cards for students
# - Add a student
# - Add a mark for a student

# %%
students = [["Ben", {"Math": 77, "English": 78, "Science": 90}], 
            ["Mark", {"Math": 56, "Art": 95, "History": 65, "Geography": 55}],
            ["Paul", {"English": 66, "History": 88}]]

# %%
grades = ((0, "Fail"), (50, "D"), (60, "C"), (70, "B"), (80, "A"), (101, "Cheat"))

# %%
def print_report_cards(report_student=None): # report_student is optional
    global students
    for student in students:
        if (student[0] == report_student) or (report_student == None):
            print("Report card for student", student[0])
            for subject, mark in student[1].items(): # code for iterating over dictionary items in students
                for grade in grades: # code for iterating over grades tuple
                    if mark < grade[0]:
                        print(subject, ":", prev_grade)
                        break
                    prev_grade = grade[1]

# %%
print_report_cards("Ben")
# Out:
# Report card for student Ben
# Math : B
# English : B
# Science : A

# %%
print_report_cards()
# Out:
# Report card for student Ben
# Math : B
# English : B
# Science : A
# Report card for student Mark
# Math : D
# Art : A
# History : C
# Geography : D
# Report card for student Paul
# English : C
# History : A

# %%
def add_student(student_name):
    global students
    for student in students:
        if student[0] == student_name:
            return "Student already in database"
    students.append([student_name, {}])
    return "Student added successfully"

# %%
def add_mark(student_name, subject, mark):
    global students
    for student in students:
        if student[0] == student_name:
            if subject in student[1].keys():
                print(student_name, "already has a mark for", subject)
                user_input = input("Overwrite Y/N?")
                if user_input == "Y" or user_input == "y":
                    student[1][subject] = mark
                    return "Students mark updated"
                else:
                    return "Students mark not updated"
            else:
                student[1][subject] = mark
                return "Students mark added"
    return "Student not found"

# %%
while True:
    print("Welcome to the student database")
    print("What can I help you with?")
    print("Enter 1 to view all report cards")
    print("Enter 2 to view the report card for a student")
    print("Enter 3 to add a student")
    print("Enter 4 to add a mark for a student")
    print("Enter 5 to exit")
    
    try:
        user_choice = int(input("Choice: "))
    except ValueError:
        print("That's not a number I recognize")
        user_choice = 0
        
    if user_choice == 1:
        print_report_cards()
    elif user_choice == 2:
        enter_student = input("Which student?: ")
        print_report_cards(enter_student)
    elif user_choice == 3:
        enter_student = input("Student name?: ")
        print(add_student(enter_student))
    elif user_choice == 4:
        enter_student = input("Student name?: ")
        enter_subject = input("Subject name?: ")
        print(add_student(enter_student))
        num_error = True
        while num_error:
            num_error = False
            try:
                enter_mark = int(input("Mark?: "))
            except ValueError:
                print("I don't recognize that as a number")
                num_error = True
        print(add_mark(enter_student, enter_subject, enter_mark))
    elif user_choice == 5:
        break
    else:
        print("Unknown choice")
    input("Press enter to continue")
print("Thanks for using the student database")
# Out:
# Welcome to the student database
# What can I help you with?
# Enter 1 to view all report cards
# Enter 2 to view the report card for a student
# Enter 3 to add a student
# Enter 4 to add a mark for a student
# Enter 5 to exit
# Choice: 1
# Report card for student Ben
# Math : B
# English : B
# Science : A
# Report card for student Mark
# Math : D
# Art : A
# History : C
# Geography : D
# Report card for student Paul
# English : C
# History : A
# Press enter to continue
# Welcome to the student database
# What can I help you with?
# Enter 1 to view all report cards
# Enter 2 to view the report card for a student
# Enter 3 to add a student
# Enter 4 to add a mark for a student
# Enter 5 to exit
# Choice: 2
# Which student?: Mark
# Report card for student Mark
# Math : D
# Art : A
# History : C
# Geography : D
# Press enter to continue
# Welcome to the student database
# What can I help you with?
# Enter 1 to view all report cards
# Enter 2 to view the report card for a student
# Enter 3 to add a student
# Enter 4 to add a mark for a student
# Enter 5 to exit
# Choice: 3
# Student name?: Jane
# Student added successfully
# Press enter to continue
# Welcome to the student database
# What can I help you with?
# Enter 1 to view all report cards
# Enter 2 to view the report card for a student
# Enter 3 to add a student
# Enter 4 to add a mark for a student
# Enter 5 to exit
# Choice: 4
# Student name?: Jane
# Subject name?: Math
# Student already in database
# Mark?: 99
# Students mark added
# Press enter to continue
# Welcome to the student database
# What can I help you with?
# Enter 1 to view all report cards
# Enter 2 to view the report card for a student
# Enter 3 to add a student
# Enter 4 to add a mark for a student
# Enter 5 to exit
# Choice: 1
# Report card for student Ben
# Math : B
# English : B
# Science : A
# Report card for student Mark
# Math : D
# Art : A
# History : C
# Geography : D
# Report card for student Paul
# English : C
# History : A
# Report card for student Jane
# Math : A
# Press enter to continue
# Welcome to the student database
# What can I help you with?
# Enter 1 to view all report cards
# Enter 2 to view the report card for a student
# Enter 3 to add a student
# Enter 4 to add a mark for a student
# Enter 5 to exit
# Choice: 4
# Student name?: Jane
# Subject name?: Physics
# Student already in database
# Mark?: 89
# Students mark added
# Press enter to continue
# Welcome to the student database
# What can I help you with?
# Enter 1 to view all report cards
# Enter 2 to view the report card for a student
# Enter 3 to add a student
# Enter 4 to add a mark for a student
# Enter 5 to exit
# Choice: 2
# Which student?: Jane
# Report card for student Jane
# Math : A
# Physics : A
# Press enter to continue
# Welcome to the student database
# What can I help you with?
# Enter 1 to view all report cards
# Enter 2 to view the report card for a student
# Enter 3 to add a student
# Enter 4 to add a mark for a student
# Enter 5 to exit
# Choice: 5
# Thanks for using the student database
