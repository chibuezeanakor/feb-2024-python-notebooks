# %%
# %pwd
# Out:
# 'C:\\Users\\santo\\Documents\\python_notebooks'

# %%
import folium
import csv

gpsTrack = open("data/gps_track.txt")

csvReader = csv.reader(gpsTrack)
header = csvReader.__next__() # two underscores
latIndex = header.index("lat")
longIndex = header.index("long")

mapa = folium.Map(location=[40.78966141, -77.85948515], zoom_start = 12)
for row in csvReader:
    lat = row[latIndex]
    lon = row[longIndex]
    folium.Marker([lat, lon]).add_to(mapa)
    
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2887a55c9caa2ada6f41bb808d74e863 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2887a55c9caa2ada6f41bb808d74e863&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2887a55c9caa2ada6f41bb808d74e863 = L.map(
#                 &quot;map_2887a55c9caa2ada6f41bb808d74e863&quot;,
#                 {
#                     center: [40.78966141, -77.85948515],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e331052c3c1133b93dd75e928804e37 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1e331052c3c1133b93dd75e928804e37.addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_6fe0236febb0b4097f13c146df6b9150 = L.marker(
#                 [40.78966141, -77.85948515],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_f95cbd17ccce5e1a604292a5a8c1d24b = L.marker(
#                 [40.78963995, -77.85954952],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_dc206de1ab0191e84ca7591e66b2f06c = L.marker(
#                 [40.78961849, -77.85957098],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_1faa367fbd20445f8eb561b17b7f44e3 = L.marker(
#                 [40.78953266, -77.85965681],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_218323bfe307a9c326c5c2d69c734f80 = L.marker(
#                 [40.78957558, -77.85972118],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_7a7bba0cf455b7bb60abbfcdecba8787 = L.marker(
#                 [40.78968287, -77.8597641],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_41a537c2f85abf46c29b643aa02a8f6d = L.marker(
#                 [40.78979015, -77.8596139],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_e1019a45169fcf6d9e1aa948fba2f0f4 = L.marker(
#                 [40.78983307, -77.8596139],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_6e11faf6d5381fc8ff4051eba9a7e823 = L.marker(
#                 [40.78987598, -77.85950661],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_8373bad62dc4e8baa80b5aeaba17ba84 = L.marker(
#                 [40.78996181, -77.85946369],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_cb9ef20e4c6bbd032983ec49f5d41073 = L.marker(
#                 [40.79011202, -77.85957098],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_e65ee3453f3b40f17751743489427344 = L.marker(
#                 [40.79015493, -77.85954952],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_77848078ee23b1912078109d34d558fd = L.marker(
#                 [40.79015493, -77.85950661],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_7c0d78ee749dd9917838be3104bda1b8 = L.marker(
#                 [40.79021931, -77.85929203],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_eb113ced2805be7fdac2f83f7b599414 = L.marker(
#                 [40.79024076, -77.85927057],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_1c4ce2a09fe311bf66537edb087d63e3 = L.marker(
#                 [40.79036951, -77.85907745],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_3f0c59d77e629ac73a624798657b359a = L.marker(
#                 [40.79036951, -77.85909891],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_d04a076e76afaaa3c1e269e8237b8dd0 = L.marker(
#                 [40.7904768, -77.85899162],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_8807a5fe7a779bf1682b61f1d6f34063 = L.marker(
#                 [40.79064846, -77.8592062],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_505cca850522adb79f7db176b64db40c = L.marker(
#                 [40.79069138, -77.85922766],
#                 {}
#             ).addTo(map_2887a55c9caa2ada6f41bb808d74e863);
#
#
#             var marker_b40b7880b2d2cd2319e3cb0a117e2

# %%
import folium
import csv

gpsTrack = open("data/pa_county_geolocation.csv")

csvReader = csv.reader(gpsTrack)
header = csvReader.__next__() # two underscores
latIndex = header.index("Latitude")
longIndex = header.index("Longitude")

mapa = folium.Map(location=[41.174964,-75.969523], zoom_start = 12)
for row in csvReader:
    lat = row[latIndex]
    lon = row[longIndex]
    folium.Marker([lat, lon]).add_to(mapa)
    
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d286119693e5fd7e7f62d97a5beb407 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d286119693e5fd7e7f62d97a5beb407&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d286119693e5fd7e7f62d97a5beb407 = L.map(
#                 &quot;map_2d286119693e5fd7e7f62d97a5beb407&quot;,
#                 {
#                     center: [41.174964, -75.969523],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdae1fdcc0b6e9958845be7b32b764d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fdae1fdcc0b6e9958845be7b32b764d1.addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_4180e7ab3d583e7030b0c53f05d16a7e = L.marker(
#                 [41.174964, -75.969523],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_d7a8405d944f2d154d04a4333233e3b6 = L.marker(
#                 [40.293016, -79.48732],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_911fea7fa9e114a64ec4e786778626c1 = L.marker(
#                 [-4.749393, -52.897301],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_f105501cb4b99ed48c7a8e52137a36c4 = L.marker(
#                 [41.51791, -76.019111],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_c6f0531412fd9db22b5d60fb96a29a23 = L.marker(
#                 [41.81196, -79.265445],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_554b490d5c458ac3176c2e9a5d3bd7d6 = L.marker(
#                 [41.399611, -79.770942],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_4c176e8571d8d2c0dcb1949b03e8bf58 = L.marker(
#                 [39.915966, -78.129962],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_409bfe0b3d0283e3f6bdadaa0d1af00e = L.marker(
#                 [41.001415, -80.350071],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_076392c56daacacae2f70604adb6ee3c = L.marker(
#                 [40.609622, -75.604873],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_7a85d3bbdefc3d08ba9299d1f7914251 = L.marker(
#                 [40.398036, -76.811517],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_714cab6d4bbde473915ca82526b1beda = L.marker(
#                 [40.990871, -78.445742],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_453cf59b6f83e9115095b305957cd946 = L.marker(
#                 [39.952399, -75.16359],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_534c05a3dd628e1ed4ebcac853660672 = L.marker(
#                 [40.17396, -80.246171],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_a5d5e7c4ed06c1fc4195dcde068ef2cc = L.marker(
#                 [41.440608, -75.626027],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_ea8e324553fb42fc8fec33238361771d = L.marker(
#                 [41.821873, -75.817077],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_18560ff26bd3d8696520473aca7d9db8 = L.marker(
#                 [39.851332, -80.246638],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_420f8b50f6929dda49ebf78f046ae1c6 = L.marker(
#                 [32.366966, -86.300648],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_bc9ac8e7a1f7704f043ce2df17ed775d = L.marker(
#                 [40.290347, -79.560318],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_0874dd1e9e59080e3ebe586bd87274ae = L.marker(
#                 [41.458699, -78.193183],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_fb99b00fa805b89c0ca2c6ec545dfa4f = L.marker(
#                 [40.154158, -77.280393],
#                 {}
#             ).addTo(map_2d286119693e5fd7e7f62d97a5beb407);
#
#
#             var marker_8701935e6c7e49aaff1e13a0791b7815 = L.marker(
#                 [-4.749393, -52.897301],
#                 {}
